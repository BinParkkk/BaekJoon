# %%
# 2739번
# N을 입력받은 뒤, 구구단 N단을 출력하는 프로그램을 작성하시오. 출력 형식에 맞춰서 출력하면 된다.

N = int(input())

for n in range(1,10) :
  print(N,'*',n,'=',N*n)

# %%
# 10950번
# 두 정수 A와 B를 입력받은 다음, A+B를 출력하는 프로그램을 작성하시오.

T = int(input())

for i in range(T) :
  A, B = map(int, input().split())
  print(A+B)

# %%
# 8393번
# n이 주어졌을 때, 1부터 n까지 합을 구하는 프로그램을 작성하시오.

n = int(input())

sum = 0
for i in range(1, n+1) :
  sum = sum + i

print(sum)


# 생각이 잘 안났음

# %%
# 15552번
# 본격적으로 for문 문제를 풀기 전에 주의해야 할 점이 있다. 입출력 방식이 느리면 여러 줄을 입력받거나 출력할 때 시간초과가 날 수 있다는 점이다.
# Python을 사용하고 있다면, input 대신 sys.stdin.readline을 사용할 수 있다. 
# 단, 이때는 맨 끝의 개행문자까지 같이 입력받기 때문에 문자열을 저장하고 싶을 경우 .rstrip()을 추가로 해 주는 것이 좋다.
# 또한 입력과 출력 스트림은 별개이므로, 테스트케이스를 전부 입력받아서 저장한 뒤 전부 출력할 필요는 없다. 테스트케이스를 하나 받은 뒤 하나 출력해도 된다.

import sys  # sys모듈 읽어들이기

T = int(input())

for i in range(T) :
  A, B = map(int, sys.stdin.readline().split())
  print(A+B)


# T = int(input())

# for i in range(T) :
#   A, B = map(int, input().split())
#   print(A+B)

# 원래 기존에 하던 map 안에 input을 통해서 했지만
# 시간초과의 이유로 문제에서 요구한 sys에 관한 정보를 검색 후 문제를 풀었음.

# 참고한 주소
# https://velog.io/@yeseolee/Python-%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EC%9E%85%EB%A0%A5-%EC%A0%95%EB%A6%ACsys.stdin.readline

# %%
# 2741번
# 자연수 N이 주어졌을 때, 1부터 N까지 한 줄에 하나씩 출력하는 프로그램을 작성하시오.

N = int(input())

for i in range(N) :
  print(i+1)

# %%
# 2742번
# 자연수 N이 주어졌을 때, N부터 1까지 한 줄에 하나씩 출력하는 프로그램을 작성하시오.

N = int(input())

for i in range(N) :
  print(N-i)

# %%
# 11021번
# 두 정수 A와 B를 입력받은 다음, A+B를 출력하는 프로그램을 작성하시오.
import sys

T = int(input())

for i in range(T) : 
  A, B = map(int, sys.stdin.readline().split())
  print(f'Case #{i+1}: {A+B}'.format())

# %%
# 11022번
# 두 정수 A와 B를 입력받은 다음, A+B를 출력하는 프로그램을 작성하시오.

import sys

T = int(input())

for i in range(T) : 
  A, B = map(int, sys.stdin.readline().split())
  print(f'Case #{i+1}: {A} + {B} = {A+B}'.format())

# %%
# 2438번
# 첫째 줄에는 별 1개, 둘째 줄에는 별 2개, N번째 줄에는 별 N개를 찍는 문제

N = int(input())

for i in range(N) :
  print('*'*(i+1))

# %%
# 2439번
# 첫째 줄에는 별 1개, 둘째 줄에는 별 2개, N번째 줄에는 별 N개를 찍는 문제
# 하지만, 오른쪽을 기준으로 정렬한 별(예제 참고)을 출력하시오.

N = int(input())

for i in range(N) :
  print(' ' * (N-i-1) + '*' * (i+1))

# 코드가 살짝 더럽 the love..♥

# %%
# 10871번
# 정수 N개로 이루어진 수열 A와 정수 X가 주어진다. 이때, A에서 X보다 작은 수를 모두 출력하는 프로그램을 작성하시오.

N, X = map(int, input().split())

A = list(map(int,input().split()))

for i in range(N) :
  if A[i] < X :
    print(A[i], end = ' ')

# %%
# 10952번
# 두 정수 A와 B를 입력받은 다음, A+B를 출력하는 프로그램을 작성하시오.

while True:
  A, B = map(int, input().split())
  if A==0 & B==0 :
    break
  print(A+B)

# %%
# 10951번
# 두 정수 A와 B를 입력받은 다음, A+B를 출력하는 프로그램을 작성하시오.

while True:
    try:
        A, B = map(int, input().split())
        print(A+B)
    except:
        break


# try, except 구문 써야하네

# try:
#     while True:
#         A, B = map(int, input().split())
#         print(A+B)
# except:
#     print("error")

# %%
# 1110번
# 0보다 크거나 같고, 99보다 작거나 같은 정수가 주어질 때 다음과 같은 연산을 할 수 있다. 
# 먼저 주어진 수가 10보다 작다면 앞에 0을 붙여 두 자리 수로 만들고, 각 자리의 숫자를 더한다. 그 다음, 주어진 수의 가장 오른쪽 자리 수와 앞에서 구한 합의 가장 오른쪽 자리 수를 이어 붙이면 새로운 수를 만들 수 있다. 
# 다음 예를 보자.
# 26부터 시작한다. 2+6 = 8이다. 새로운 수는 68이다. 6+8 = 14이다. 새로운 수는 84이다. 8+4 = 12이다. 
# 새로운 수는 42이다. 4+2 = 6이다. 새로운 수는 26이다.
# 위의 예는 4번만에 원래 수로 돌아올 수 있다. 
# 따라서 26의 사이클의 길이는 4이다.
# N이 주어졌을 때, N의 사이클의 길이를 구하는 프로그램을 작성하시오.

N = input()
A = N
i = 1

while True :
  if len(A) < 2 :
    A = str('0'+A)   # A = str(int(A) * 10 ) 하고 있었음

  a = int(A[0])
  b = int(A[1])

  c = (a+b)%10

  if b*10 + c == int(N) :
    print(i) 
    break
    
  i = i + 1
  A = str(b*10 + c)

# 앞에 0을 붙인다는게 1을 넣었을때 10이 되는 게 아니라 01이 되는거였음

# num = int(input())
# check = num
# new_num = 0
# temp = 0
# count = 0
# while True:
#     temp = num//10 + num%10
#     new_num = (num%10)*10 + temp%10
#     count += 1
#     num = new_num
#     if new_num == check:
#         break
# print(count)
# Out:
# 1
# 60

# %%
# 규원이랑 한거....
# 9498번 ..

score = int(input())

while True : 
  if score > 100 :
    score = int(input("다시 입력하세요 : "))

  if score <= 100 :
    break
# Out:
# 105
# 다시 입력하세요 : 101
# 다시 입력하세요 : 99
